# %%
import matplotlib.pyplot as plt

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotx
import pandas as pd
import os

import pickle

from tmu.models.autoencoder.autoencoder import TMAutoEncoder
from src.lib.care import calculate_care_score

# use everywhere:
plt.style.use("seaborn-v0_8")

# %%
# Create folder figures if it does not exist
os.makedirs("figures", exist_ok=True)
os.makedirs("predictions", exist_ok=True)

# %%
def load_test_dataset(farm, event_id):
    X = np.loadtxt(f"./data_test/X_{farm}_{event_id}.txt", dtype=np.uint32)
    X = np.array(X).astype(np.uint32)
    return X


def load_thresh_dataset(farm, event_id):
    X = np.loadtxt(f"./data_test/X_{farm}_{event_id}.txt", dtype=np.uint32)
    X = np.array(X).astype(np.uint32)

    # Take the first 5000 rows
    X = X[:10000]
    return X


def load_test_labels(farm, event_id):
    # Load dataframe from file
    df = pd.read_csv(f"./data_test/y_{farm}_{event_id}.csv")

    labels = df['label'].values
    status_ids = df['status_type_id'].values
    train_test = df['train_test'].values

    return np.array(labels).astype(np.uint32), np.array(status_ids).astype(np.uint32), train_test


def load_test_label(farm, event_id):
    event_info = pd.read_csv(f"../../../data/care_to_compare/Wind Farm {farm}/event_info.csv", delimiter=';')

    metadata = event_info[event_info['event_id'] == event_id]

    event_label = metadata["event_label"].values[0]

    return False if event_label == "anomaly" else True

# %%
def calculate_accuracy(labels, predictions):
    # Calculate the accuracy
    accuracy = np.sum(labels == predictions) / len(labels)

    return accuracy


def calculate_threshold(X, pred):
    losses = [hamming_loss(X[i], pred[i]) for i in range(len(X))]

    # Set the threshold as the lowest 1% of the losses
    threshold = np.percentile(losses, 90)

    return threshold

# %%
def load_model(filename) -> TMAutoEncoder:
    with open(filename, "rb") as f:
        model = pickle.load(f)

    return model


def save_predictions(predictions, filename):
    with open(filename, "wb") as f:
        pickle.dump(predictions, f)


def load_predictions(filename):
    with open(filename, "rb") as f:
        predictions = pickle.load(f)

    return predictions

# %%
def hamming_loss(pred, X_test):
    """
    Computes the Hamming loss between predicted and ground truth binary arrays.

    Parameters:
    - pred (numpy array): Binary predictions of shape (n_samples, n_bits).
    - X_test (numpy array): Ground truth binary values of shape (n_samples, n_bits).

    Returns:
    - float: Hamming loss (fraction of incorrect bits).
    """
    assert pred.shape == X_test.shape, "Shapes of pred and X_test must match"

    # Compute the number of differing bits
    incorrect_bits = np.sum(pred != X_test)

    # Total number of bits
    total_bits = np.prod(X_test.shape)

    # Hamming loss is the fraction of incorrect bits
    return incorrect_bits / total_bits

# %%
def reconstruction_accuracy(X, pred):
    correct = np.sum(X == pred)
    accuracy = correct / len(X)
    return accuracy


def plot_mse(X, y, pred, name, threshold):
    # Compute MSE for each row
    mse_per_row = [hamming_loss(X[i], pred[i]) for i in range(len(X))]

    # Plot SNS plot of all MSE values
    plt.figure(figsize=(8, 4))
    sns.histplot(mse_per_row, bins=50, kde=True, color='b')

    # Add a threshold line
    plt.axvline(threshold, color='r', linestyle='--')

    # Save the plot
    plt.savefig(f"./figures/plot_reconstruction_acc_{name}.png")

    plt.close()


def plot_predictions(X, y, z, pred, p, name, plot_name, threshold):
    x = np.arange(0, len(X))  # Time or index
    r = [hamming_loss(X[i], pred[i]) for i in range(len(X))]

    if np.sum(y) < 1:
        start_idx = 0
        end_idx = 0
    else:
        start_idx = np.where(y == 1)[0][0]
        end_idx = np.where(y == 1)[0][-1]

    # Create a figure with two subplots (1 row, 2 columns)
    fig, axes = plt.subplots(figsize=(12, 10))

    # Filter data points into normal and anomaly sets
    normal_indices = [i for i in range(len(p)) if p[i] == 0]
    anomaly_indices = [i for i in range(len(p)) if p[i] == 1]

    # Get corresponding x values and reconstruction loss values for each set
    normal_x = [x[i] for i in normal_indices]
    normal_r = [r[i] for i in normal_indices]

    anomaly_x = [x[i] for i in anomaly_indices]
    anomaly_r = [r[i] for i in anomaly_indices]

    # Plot the two scatter plots separately
    axes.axvspan(start_idx, end_idx, alpha=0.2, color='#d08770', label="Region with anomalies")
    axes.scatter(normal_x, normal_r, color='#81a1c1', label="Predicted normal", alpha=0.7)
    axes.scatter(anomaly_x, anomaly_r, color='#d08770', label="Predicted anomaly", alpha=0.7)
    axes.axhline(threshold, color='#5e81ac', linestyle='--', label="Threshold")

    axes.set_title(plot_name)
    axes.set_xlabel("Time\nSampled at ten minute intervals")
    axes.set_ylabel("Reconstruction Loss\n(Hamming Loss)")
    axes.legend()

    # Adjust layout
    plt.tight_layout()
    plt.grid(True)

    # plt.show()

    # Save the plot
    plt.savefig(f"./figures/plot_detections_{name}.pdf")

    plt.close()


def get_predictions(X, y, z, name, plot_name, tm, threshold, load_pred=False):
    if load_pred:
        pred = load_predictions(f"./predictions/predictions_{name}.pkl")
    else:
        pred = tm.predict(X)

    # Save predictions
    save_predictions(pred, f"./predictions/predictions_{name}.pkl")

    # For each row in pred, if the MSE is greater than the threshold, then it is an anomaly
    losses = [hamming_loss(X[i], pred[i]) for i in range(len(X))]

    X_predictions = np.array([1 if losses[i] > threshold else 0 for i in range(len(X))])

    # Accuracy
    accuracy = calculate_accuracy(y, X_predictions)

    plot_mse(X, y, pred, name, threshold)
    plot_predictions(X, y, z, pred, X_predictions, name, plot_name, threshold)

    return X_predictions, accuracy

# %%
test_datasets = [47, 12, 4, 18, 28, 39, 66, 15, 78, 79, 30, 33, 11, 44, 49, 31, 67, 9, 91, 5, 90, 35, 16,
                 76, 8, 85, 6, 62, 36, 56, 94, 54, 43, 50, 64, 46, 65, 61, 93, 75, 41, 58, 48, 88, 57, 32, 89, 59, 63,
                 80, 37, 29, 1, 20, 60]

# 18, 28, 39, 66, 15, 78, 79, 30, 33, 11, 44, 49, 31, 67, 9, 91, 5, 90, 70, 35, 16, 76, 8, 85, 6, 62, 36, 56, 94, 54, 43, 50, 64, 46, 65, 61, 93, 75, 41, 58, 48, 88, 57, 32, 89, 59, 63, 80, 37, 29,
tm_autoencoder = load_model("models/latest_2.pkl")

#X_thresh = load_thresh_dataset("C", 12)
#X_thresh_pred = tm_autoencoder.predict(X_thresh)
#threshold = calculate_threshold(X_thresh, X_thresh_pred)

threshold = 0.531

print(f"Threshold: {threshold}")


def run_prediction(farm, dataset, load_pred=False):
    X = load_test_dataset(farm, dataset)
    labels, status_ids, train_test = load_test_labels(farm, dataset)

    is_normal = load_test_label(farm, dataset)

    predictions, accuracy = get_predictions(X, labels, status_ids, f"{farm}_{dataset}",
                                            f"Anomaly prediction using Tsetlin Autoencoder\nWind farm {farm} - Dataset {dataset}",
                                            tm_autoencoder, threshold,
                                            load_pred)

    return X, labels, status_ids, train_test, is_normal, predictions, accuracy
# Out:
# Threshold: 0.531

# %%
# Create a dataframe with status_type_id;label;prediction
elements = []

lp = True

for set in test_datasets:
    res = run_prediction("C", set, load_pred=lp)

    result_df = pd.DataFrame({
        'status_type_id': res[2],
        'label': res[1],
        'prediction': res[5],
        'train_test': res[3],
    })

    print(f"Done with {set}. Accuracy: {res[6]}")

    elements.append({'dataset': set, 'normal': res[4], 'data': result_df, 'accuracy': res[6]})
# Out:
# 2025-05-03 18:01:01,462 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:01,549 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:01,550 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 47. Accuracy: 0.5478757133798351
# 2025-05-03 18:01:02,422 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:02,495 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:02,496 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 12. Accuracy: 0.3433887792500705
# 2025-05-03 18:01:03,326 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:03,382 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:03,383 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 4. Accuracy: 0.3864746721522242
# 2025-05-03 18:01:04,076 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:04,147 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:04,147 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 18. Accuracy: 0.6666666666666666
# 2025-05-03 18:01:05,035 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:05,112 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:05,112 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 28. Accuracy: 0.13639070875521145
# 2025-05-03 18:01:05,712 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:05,756 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:05,756 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 39. Accuracy: 0.37017994858611825
# 2025-05-03 18:01:06,403 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:06,441 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:06,441 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 66. Accuracy: 0.4781405644714997
# 2025-05-03 18:01:07,209 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:07,290 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:07,290 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 15. Accuracy: 0.10522469857508221
# 2025-05-03 18:01:07,699 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:07,729 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:07,729 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 78. Accuracy: 0.49146757679180886
# 2025-05-03 18:01:08,034 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:08,074 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:08,075 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 79. Accuracy: 0.5991678224687933
# 2025-05-03 18:01:09,082 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:09,190 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:09,191 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 30. Accuracy: 0.08110391439031259
# 2025-05-03 18:01:10,008 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:10,067 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:10,067 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 33. Accuracy: 0.1352248717174766
# 2025-05-03 18:01:10,990 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:11,040 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:11,041 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 11. Accuracy: 0.2944541158915693
# 2025-05-03 18:01:14,595 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:15,140 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:15,141 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 44. Accuracy: 0.1087810016278847
# 2025-05-03 18:01:15,919 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:15,962 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:15,962 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 49. Accuracy: 0.636986301369863
# 2025-05-03 18:01:16,648 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:16,700 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:16,700 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 31. Accuracy: 0.4795465746673238
# 2025-05-03 18:01:18,487 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:18,605 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:18,605 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 67. Accuracy: 0.06450890357262852
# 2025-05-03 18:01:19,496 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:19,551 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:19,551 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 9. Accuracy: 0.19400403574517153
# 2025-05-03 18:01:20,373 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:20,457 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:20,459 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 91. Accuracy: 0.29347826086956524
# 2025-05-03 18:01:20,792 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:20,822 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:20,823 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 5. Accuracy: 0.2158920539730135
# 2025-05-03 18:01:21,344 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:21,384 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:21,385 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 90. Accuracy: 0.2482758620689655
# 2025-05-03 18:01:21,761 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:21,794 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:21,794 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 35. Accuracy: 0.23860811930405965
# 2025-05-03 18:01:22,311 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:22,355 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:22,355 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 16. Accuracy: 0.15625
# 2025-05-03 18:01:22,654 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:22,681 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:22,682 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 76. Accuracy: 0.537712895377129
# 2025-05-03 18:01:23,221 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:23,259 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:23,259 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 8. Accuracy: 0.7011596788581623
# 2025-05-03 18:01:23,733 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:23,794 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:23,794 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 85. Accuracy: 0.9362776025236593
# 2025-05-03 18:01:24,442 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:24,500 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:24,501 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 6. Accuracy: 0.9904555314533623
# 2025-05-03 18:01:24,926 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:24,989 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:24,992 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 62. Accuracy: 0.8313953488372093
# 2025-05-03 18:01:26,133 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:26,249 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:26,252 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 36. Accuracy: 1.0
# 2025-05-03 18:01:27,308 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:27,369 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:27,370 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 56. Accuracy: 0.8371080139372822
# 2025-05-03 18:01:28,299 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:28,360 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:28,360 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 94. Accuracy: 1.0
# 2025-05-03 18:01:29,327 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:29,375 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:29,375 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 54. Accuracy: 0.9358677685950413
# 2025-05-03 18:01:30,580 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:30,691 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:30,692 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 43. Accuracy: 1.0
# 2025-05-03 18:01:32,002 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:32,062 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:32,063 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 50. Accuracy: 0.7457332947642464
# 2025-05-03 18:01:32,628 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:32,678 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:32,678 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 64. Accuracy: 1.0
# 2025-05-03 18:01:33,291 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:33,335 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:33,336 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 46. Accuracy: 1.0
# 2025-05-03 18:01:34,065 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:34,111 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:34,112 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 65. Accuracy: 0.9997022036926743
# 2025-05-03 18:01:34,886 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:34,936 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:34,936 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 61. Accuracy: 0.9613223140495868
# 2025-05-03 18:01:35,923 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:35,978 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:35,978 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 93. Accuracy: 0.9215212798068216
# 2025-05-03 18:01:36,709 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:36,758 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:36,758 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 75. Accuracy: 0.8381005276312136
# 2025-05-03 18:01:37,559 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:37,607 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:37,607 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 41. Accuracy: 1.0
# 2025-05-03 18:01:38,125 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:38,166 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:38,166 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 58. Accuracy: 1.0
# 2025-05-03 18:01:38,950 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:38,993 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:38,993 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 48. Accuracy: 0.855681402995981
# 2025-05-03 18:01:39,796 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:39,860 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:39,860 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 88. Accuracy: 1.0
# 2025-05-03 18:01:40,439 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:40,476 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:40,476 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 57. Accuracy: 0.9718252347897101
# 2025-05-03 18:01:41,005 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:41,050 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:41,050 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 32. Accuracy: 1.0
# 2025-05-03 18:01:41,655 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:41,691 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:41,691 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 89. Accuracy: 0.9652904640116916
# 2025-05-03 18:01:42,265 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:42,304 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:42,305 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 59. Accuracy: 1.0
# 2025-05-03 18:01:42,947 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:43,000 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:43,001 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 63. Accuracy: 0.9067245119305857
# 2025-05-03 18:01:43,695 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:43,768 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:43,770 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 80. Accuracy: 0.8066298342541437
# 2025-05-03 18:01:44,612 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:44,767 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:44,768 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 37. Accuracy: 0.9060841159657003
# 2025-05-03 18:01:45,767 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:45,810 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:45,810 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 29. Accuracy: 0.8321041214750542
# 2025-05-03 18:01:46,353 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:46,416 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:46,416 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 1. Accuracy: 1.0
# 2025-05-03 18:01:47,826 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:47,880 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:47,881 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 20. Accuracy: 1.0
# 2025-05-03 18:01:48,467 - matplotlib.backends.backend_pdf - DEBUG - Assigning font /F1 = '/System/Library/Fonts/Supplemental/Arial.ttf'
# 2025-05-03 18:01:48,504 - matplotlib.backends.backend_pdf - DEBUG - Embedding font /System/Library/Fonts/Supplemental/Arial.ttf.
# 2025-05-03 18:01:48,504 - matplotlib.backends.backend_pdf - DEBUG - Writing TrueType font.
# Done with 60. Accuracy: 0.7215189873417721

# %%
import src.lib.care as care

score = care.calculate_care_score(elements)
print(score)
# Out:
# 0.6897384409275394

# %%
# To beat 0.688609158102485 (0.531 threshold)
